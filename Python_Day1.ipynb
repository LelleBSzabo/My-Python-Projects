# %% [markdown]
# <a href="https://colab.research.google.com/github/LelleBSzabo/My-Python-Projects/blob/main/Python_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.12.12

# %% [markdown]
# I am learning Python

# %% [markdown]
# # this is a title

# %% [markdown]
# ## sub-title

# %% [markdown]
# ### smaller

# %% [markdown]
# * bullet point
# * bullet point

# %% [markdown]
# *italic*

# %% [markdown]
# **bold**

# %% [markdown]
# # another title

# %%
print('hello world!')
# Out:
# hello world!

# %%
print("My Name is Lelle.")
# Out:
# My Name is Lelle.

# %%
print(3.14)
# Out:
# 3.14

# %%
print(type("3.14"))
# Out:
# <class 'str'>

# %%
print(type(3.14))

# %%
print("3.14"*2)
# Out:
# 3.143.14

# %%
print(3.14*2)
# Out:
# 6.28

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")
print()
print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.
#
# Down came the rain
# and washed the spider out.

# %%
print("Hello \nWorld")
# Out:
# Hello
# World

# %%
print("C:\\new_folder\\test.txt")
# Out:
# C:\new_folder\test.txt

# %%
print('She said: "Python is fun!"')
# Out:
# She said: "Python is fun!"

# %%
print("Hi.","My name is Lelle.","I am learning Python.")
# Out:
# Hi. My name is Lelle. I am learning Python.

# %%
print("Hi"*7)
# Out:
# HiHiHiHiHiHiHi

# %%
print("Hi."+"My name is Lelle."+"I am learning Python.")
# Out:
# Hi.My name is Lelle.I am learning Python.

# %%
print("1+1=",1+1)
# Out:
# 1+1= 2

# %%
print(13+5)
# Out:
# 18

# %%
print(13/5)
# Out:
# 2.6

# %%
print(13*5)
# Out:
# 65

# %%
print(13%5)
# Out:
# 3

# %%
print(13//5)
# Out:
# 2

# %%
print(13**5)
# Out:
# 371293

# %%
print(17//4)
# Out:
# 4

# %%
print(17%4)
# Out:
# 1

# %%
print(100**0.5)
# Out:
# 10.0

# %%
#square root of 100
print(100**0.5)
# Out:
# 10.0

# %% [markdown]
# #Variables

# %%
myname="Lelle"
# my name is declared in memory now

# %%
print(myname)
# Out:
# Lelle

# %%
myage=20

# %%
print(myage)
# Out:
# 20

# %%
username = "ABC123"
password = "12345"

# %%
myage=33
yourage=30
myage=yourage
print(myage)
# Out:
# 30

# %%
myName="Lelle"

print(myName)
# Out:
# Lelle

# %%
print(type(myName))
# Out:
# <class 'str'>

# %%
print(len(myName))
# Out:
# 5

# %% [markdown]
# #input function

# %%
print("Tell me anything")
anything=input()
print("Hmm", anything, "interesting")
# Out:
# Tell me anything
# efhskgfu
# Hmm efhskgfu interesting

# %%
print("This is simple calculator")

number1 = input("Enter first number:")

number2 = input("Enter second number:")

print(number1, "+", number2, "=", number1+number2)
# Out:
# This is simple calculator
# Enter first number:7
# Enter second number:7
# 7 + 7 = 77

# %% [markdown]
# #Casting or type conversion

# %%
myage = "20"
print(type(myage))

# 20 is string here
# Out:
# <class 'str'>

# %%
print (int(myage))
myage=int(myage)

# converted to integer
# Out:
# 20

# %%
print(myage*2)
# Out:
# 40

# %%
print("This is a simple calculator.")

number1=float(input("Enter first number:"))

number2=float(input("Enter second number:"))

print(number1, "/", number2, "=", number1/number2)
# Out:
# This is a simple calculator.
# Enter first number:77
# Enter second number:12
# 77.0 / 12.0 = 6.416666666666667

# %%
# you cant convert decimal to integer, computer not smart enough

# %%
time_hour = float(input("Tell me time in hours, I will calculate in seconds"))
print("Time in seconds is", time_hour*60*60)
# Out:
# Tell me time in hours, I will calculate in seconds7
# Time in seconds is 25200.0
